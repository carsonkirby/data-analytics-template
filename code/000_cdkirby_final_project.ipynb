# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By 
from selenium.webdriver.chrome.service import Service 
from webdriver_manager.chrome import ChromeDriverManager 
import time
import random

# %%
browser = webdriver.Chrome()


url = "https://www.icip.iastate.edu/tables/population/census-counties"
browser.get(url)


table = browser.find_element(By.CLASS_NAME, "icip-table-left-2")  


header_elements = table.find_elements(By.XPATH, ".//th[@scope='col']")
headers = [header.text for header in header_elements]

# Create a dictionary to store data by columns
data = {header: [] for header in headers}

# Extract rows
rows = table.find_elements(By.XPATH, ".//tr")

for row in rows:
    cells = row.find_elements(By.XPATH, ".//td")
    if cells:
        for header, cell in zip(headers, cells):
            data[header].append(cell.text)

# Convert dictionary to a pandas DataFrame
iowa_counties = pd.DataFrame(data)
display(df)

# Optionally save to CSV
iowa_counties.to_csv('county_data.csv', index=False)

# Close the browser
browser.quit()
# Out:
#      FIPS          Area Name       1980       1990       2000       2010  \
# 0   19000      State of Iowa  2,913,808  2,776,755  2,926,324  3,046,355
# 1   19001       Adair County      9,509      8,409      8,243      7,682
# 2   19003       Adams County      5,731      4,866      4,482      4,029
# 3   19005   Allamakee County     15,108     13,855     14,675     14,330
# 4   19007   Appanoose County     15,511     13,743     13,721     12,887
# ..    ...                ...        ...        ...        ...        ...
# 95  19189   Winnebago County     13,010     12,122     11,723     10,866
# 96  19191  Winneshiek County     21,876     20,847     21,310     21,056
# 97  19193    Woodbury County    100,884     98,276    103,877    102,172
# 98  19195       Worth County      9,075      7,991      7,909      7,598
# 99  19197      Wright County     16,319     14,269     14,334     13,229
#
#          2020
# 0   3,190,369
# 1       7,496
# 2       3,704
# 3      14,061
# ...
